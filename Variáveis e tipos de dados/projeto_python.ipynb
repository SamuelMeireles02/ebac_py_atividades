# %%
print ("olá mundo!")
# Out:
# olá mundo!

# %% [markdown]
# ![sol aesthetic.jpg](data:image/jpeg;base64,...)

# %%
# (A)

# %%
# (B)

# %%
# (C)

# %%
cancao = 'mundo, roda gigante, roda moinho, roda pião.'
x = cancao. capitalize ()
type (cancao)
print (x)
# Out:
# Mundo, roda gigante, roda moinho, roda pião.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

# %%
a = False
b = True

x = not a & b
print (x)
# Out:
# True
